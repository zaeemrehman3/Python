# %%
def chalo():
   print("chalo bhai shuru karte hain")

# %%
chalo()
# Out:
# chalo bhai shuru karte hain

# %%
chalo()
# Out:
# chalo bhai shuru karte hain

# %%
chalo()
# Out:
# chalo bhai shuru karte hain

# %%
chalo()
# Out:
# chalo bhai shuru karte hain

# %%
chalo()
# Out:
# chalo bhai shuru karte hain

# %%
chalo()
# Out:
# chalo bhai shuru karte hain

# %%
chalo()
# Out:
# chalo bhai shuru karte hain
