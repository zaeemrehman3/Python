# %%
def chalo():
   print("chalo bhai shuru karte hain")

# %%
chalo()
# Out:
# chalo bhai shuru karte hain

# %%
chalo()
# Out:
# chalo bhai shuru karte hain

# %%
chalo()
# Out:
# chalo bhai shuru karte hain

# %%
chalo()
# Out:
# chalo bhai shuru karte hain

# %%
chalo()
# Out:
# chalo bhai shuru karte hain

# %%
chalo()
# Out:
# chalo bhai shuru karte hain

# %%
chalo()
# Out:
# chalo bhai shuru karte hain

# %%
def sayhello():
    print("oo kiii haaal haiiii")

# %%
sayHello()
# Out:
# Hello World

# %%
sayHello()
# Out:
# Hello World

# %%
sayHello()
# Out:
# Hello World

# %%
sayHello()
# Out:
# Hello World

# %%
sayHello()
# Out:
# Hello World
